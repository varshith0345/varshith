# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
k=[4,2.56789,9,87,9999,40,'hyderabad']

# %%
k
# Out:
# [4, 2.56789, 9, 87, 9999, 40, 'hyderabad']

# %%
pd.Series(k)
# Out:
# 0            4
# 1      2.56789
# 2            9
# 3           87
# 4         9999
# 5           40
# 6    hyderabad
# dtype: object

# %%
a=np.random.randint(20,50,(5,4))

# %%
a
# Out:
# array([[20, 49, 29, 23],
#        [39, 37, 34, 30],
#        [36, 31, 33, 26],
#        [34, 26, 46, 49],
#        [41, 24, 24, 26]])

# %%
a=np.random.randint(20,50,15)

# %%
a
# Out:
# array([20, 46, 48, 40, 21, 24, 42, 20, 33, 26, 22, 34, 45, 33, 23])

# %%
pd.Series(a)
# Out:
# 0     20
# 1     46
# 2     48
# 3     40
# 4     21
# 5     24
# 6     42
# 7     20
# 8     33
# 9     26
# 10    22
# 11    34
# 12    45
# 13    33
# 14    23
# dtype: int64

# %%
b=np.random.randint(100,200,(6,5))

# %%
b.ndim
# Out:
# 2

# %%
b
# Out:
# array([[133, 171, 166, 193, 160],
#        [187, 133, 146, 148, 176],
#        [176, 191, 182, 197, 151],
#        [174, 184, 136, 130, 136],
#        [132, 151, 169, 182, 119],
#        [177, 133, 109, 172, 156]])

# %%
pd.DataFrame(b)
# Out:
#      0    1    2    3    4
# 0  133  171  166  193  160
# 1  187  133  146  148  176
# 2  176  191  182  197  151
# 3  174  184  136  130  136
# 4  132  151  169  182  119
# 5  177  133  109  172  156

# %%
df=pd.DataFrame(b,columns=['Roll','Name','age','adds','country'])

# %%
df
# Out:
#    Roll  Name  age  adds  country
# 0   133   171  166   193      160
# 1   187   133  146   148      176
# 2   176   191  182   197      151
# 3   174   184  136   130      136
# 4   132   151  169   182      119
# 5   177   133  109   172      156

# %%
df=pd.DataFrame(b,columns=['Roll','Name','age','adds','country'],index=[182,184,185,186,188,189])

# %%
df
# Out:
#      Roll  Name  age  adds  country
# 182   133   171  166   193      160
# 184   187   133  146   148      176
# 185   176   191  182   197      151
# 186   174   184  136   130      136
# 188   132   151  169   182      119
# 189   177   133  109   172      156

# %%
df.loc[186]
# Out:
# Roll       174
# Name       184
# age        136
# adds       130
# country    136
# Name: 186, dtype: int64

# %%
df.iloc[0]
# Out:
# Roll       133
# Name       171
# age        166
# adds       193
# country    160
# Name: 182, dtype: int64

# %%
df.iloc[0,0]
# Out:
# 133

# %%
df.iloc[0,0:3]
# Out:
# Roll    133
# Name    171
# age     166
# Name: 182, dtype: int64

# %%
df.iloc[0,[0,1,2]]
# Out:
# Roll    133
# Name    171
# age     166
# Name: 182, dtype: int64

# %%
df.iloc[[0,5]]
# Out:
#      Roll  Name  age  adds  country
# 182   133   171  166   193      160
# 189   177   133  109   172      156

# %%
df.iloc[[1,3, 4]]
# Out:
#      Roll  Name  age  adds  country
# 184   187   133  146   148      176
# 186   174   184  136   130      136
# 188   132   151  169   182      119

# %%
df.loc[[184,185,186]]
# Out:
#      Roll  Name  age  adds  country
# 184   187   133  146   148      176
# 185   176   191  182   197      151
# 186   174   184  136   130      136

# %%
df[['age','adds']]
# Out:
#      age  adds
# 182  166   193
# 184  146   148
# 185  182   197
# 186  136   130
# 188  169   182
# 189  109   172

# %%
df[['age','adds','Roll']]
# Out:
#      age  adds  Roll
# 182  166   193   133
# 184  146   148   187
# 185  182   197   176
# 186  136   130   174
# 188  169   182   132
# 189  109   172   177

# %%
df[['Name','country']]
# Out:
#      Name  country
# 182   171      160
# 184   133      176
# 185   191      151
# 186   184      136
# 188   151      119
# 189   133      156

# %%
df.loc[[184,185,186],['Name','country']]
# Out:
#      Name  country
# 184   133      176
# 185   191      151
# 186   184      136

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
n=sns.load_dataset('titanic')
n
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
type(n)
# Out:
# pandas.core.frame.DataFrame

# %%
n.shape
# Out:
# (891, 15)

# %%
n.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
