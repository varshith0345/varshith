# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, StratifiedKFold

# %%
dataframe = pd.read_csv("diabetes.csv")
dataframe
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %% [markdown]
# #### **Overview of Pima Indian diabetes dataset**
#
# -Preg	Number of times pregnant	Numeric	[0, 17]
#
# -Gluc	Plasma glucose concentration at 2 Hours in an oral glucose tolerance test (GTIT)	Numeric	[0, 199]
#
# -BP	Diastolic Blood Pressure (mm Hg)	Numeric	[0, 122]
#
# -Skin	Triceps skin fold thickness (mm)	Numeric	[0, 99]
#
# -Insulin	2-Hour Serum insulin (µh/ml)	Numeric	[0, 846]
#
# -BMI	Body mass index [weight in kg/(Height in m)]	Numeric	[0, 67.1]
#
# -DPF	Diabetes pedigree function	Numeric	[0.078, 2.42]
#
# -Age	Age (years)	Numeric	[21, 81]
#
# -Outcome	Binary value indicating non-diabetic /diabetic	Factor	[0,1]

# %%
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
X = dataframe.iloc[:,0:8]
Y = dataframe.iloc[:,8]
kfold = StratifiedKFold(n_splits=10,random_state= 3,shuffle=True)
model = RandomForestClassifier(n_estimators= 200,random_state= 20,max_depth=None)
results = cross_val_score(model, X, Y, cv=kfold)
print(results)
print(results.mean())
# Out:
# [0.75324675 0.76623377 0.75324675 0.80519481 0.87012987 0.84415584
#  0.74025974 0.68831169 0.72368421 0.78947368]
# 0.7733937115516063

# %%
# Use Grid search CV to find best parameters (Hyper parameter tuning)
from sklearn.model_selection import GridSearchCV
rf = RandomForestClassifier (random_state=42, n_jobs=-1)
params = {
'max_depth': [2,3,5, None],
'min_samples_leaf': [5,10,20],
'n_estimators': [50,100,200,500],
'max_features': ["sqrt","log2", None]
}
# Instantiate the grid search model
grid_search = GridSearchCV (estimator=rf,
param_grid=params,
cv = 5,
n_jobs=-1, verbose=10, scoring="accuracy")
grid_search.fit(X, Y)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV 4/5; 1/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50
# [CV 4/5; 1/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.778 total time=   0.1s
# [CV 3/5; 3/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200
# [CV 3/5; 3/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.740 total time=   0.2s
# [CV 4/5; 4/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 4/5; 4/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.765 total time=   0.5s
# [CV 5/5; 7/144] START max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=200
# [CV 5/5; 7/144] END max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=200;, score=0.758 total time=   0.2s
# [CV 3/5; 9/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=50
# [CV 3/5; 9/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=50;, score=0.747 total time=   0.1s
# [CV 5/5; 9/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=50
# [CV 5/5; 9/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=50;, score=0.765 total time=   0.1s
# [CV 3/5; 10/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=100
# [CV 3/5; 10/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=100;, score=0.740 total time=   0.1s
# [CV 1/5; 11/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=200
# [CV 1/5; 11/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=200;, score=0.740 total time=   0.2s
# [CV 2/5; 12/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=500
# [CV 2/5; 12/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=500;, score=0.727 total time=   0.6s
# [CV 4/5; 15/144] START max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=200
# [CV 4/5; 15/144] END max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=200;, score=0.771 total time=   0.1s
# [CV 5/5; 16/144] START max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=500
# [CV 5/5; 16/144] END max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=500;, score=0.758 total time=   0.5s
# [CV 5/5; 19/144] START max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=200
# [CV 5/5; 19/144] END max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=200;, score=0.765 total time=   0.3s
# [CV 2/5; 21/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=50
# [CV 2/5; 21/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=50;, score=0.747 total time=   0.1s
# [CV 4/5; 21/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=50
# [CV 4/5; 21/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=
144] START max_depth=3, max_features=log2, min_samples_leaf=5, n_estimators=200[CV 1/5; 1/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50
# [CV 1/5; 1/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.740 total time=   0.1s
# [CV 5/5; 2/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100
# [CV 5/5; 2/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.758 total time=   0.2s
# [CV 2/5; 4/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 2/5; 4/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.734 total time=   0.7s
# [CV 4/5; 8/144] START max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=500
# [CV 4/5; 8/144] END max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=500;, score=0.765 total time=   0.5s
# [CV 5/5; 11/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=200
# [CV 5/5; 11/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=200;, score=0.758 total time=   0.2s
# [CV 1/5; 13/144] START max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=50
# [CV 1/5; 13/144] END max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=50;, score=0.753 total time=   0.1s
# [CV 3/5; 13/144] START max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=50
# [CV 3/5; 13/144] END max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=50;, score=0.734 total time=   0.1s
# [CV 2/5; 14/144] START max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=100
# [CV 2/5; 14/144] END max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=100;, score=0.747 total time=   0.2s
# [CV 2/5; 15/144] START max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=200
# [CV 2/5; 15/144] END max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=200;, score=0.747 total time=   0.3s
# [CV 4/5; 17/144] START max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=50
# [CV 4/5; 17/144] END max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=50;, score=0.765 total time=   0.1s
# [CV 1/5; 18/144] START max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=100
# [CV 1/5; 18/144] END max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=100;, score=0.734 total time=   0.2s
# [CV 3/5; 19/144] START max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=200
# [CV 3/5; 19/144] END max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=200;, score=0.747 total time=   0.3s
# [CV 1/5; 21/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=50
# [CV 1/5; 21/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=50;, score=0.747 total time=   0.1s
# [CV 5/5; 21/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=50
# [CV 5/5; 21/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=50;, score=0.771 total time=   0.2s
# [CV 1/5; 23/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=200
# [CV 1/5; 23/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=200;, score=0.740 total time=   0.2s
# [CV 4/5; 24/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=500
# [CV 4/5; 24/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=500;, score=0.778 total time=   0.6s
# [CV 2/5; 28/144] START max_depth=2, max_features=None, min_samples_leaf=5, n_estimators=500
# [CV 2/5; 28/144] END max_depth=2, max_features=None, min_samples_leaf=5, n_estimators=500;, score=0.708 total time=   0.5s
# [CV 4/5; 30/144] START max_depth=2, max_features=None, min_samples_leaf=10, n_estimators=100
# [CV 4/5; 30/144] END max_depth=2, max_features=None, min_samples_leaf=10, n_estimators=100;, score=0.765 total time=   0.1s
# [CV 5/5; 31/144] START max_depth=2, max_features=None, min_samples_leaf=10, n_estimators=200
# [CV 5/5; 31/144] END max_depth=2, max_features=None, min_samples_leaf=10, n_estimators=200;, score=0.758 total time=   0.2s
# [CV 1/5; 33/144] START max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=50
# [CV 1/5; 33/144] END max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=50;, score=0.727 total time=   0.1s
# [CV 5/5; 33/144] START max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=50
# [CV 5/5; 33/144] END max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=50;, score=0.765 total time=   0.1s
# [CV 3/5; 34/144] START max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=100
# [CV 3/5; 34/144] END max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=100;, score=0.727 total time=   0.1s
# [CV 2/5; 35/144] START max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=200
# [CV 2/5; 35/144] END max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=200;, score=0.708 total time=   0.3s
# [CV 4/5; 36/144] START max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=500
# [CV 4/5; 36/144] END max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=500;, score=0.771 total time=   0.5s
# [CV 4/5; 39/144] START max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=200
# [CV 4/5; 39/144] END max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.791 total time=   0.2s
# [CV 4/5; 40/144] START max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 4/5; 40/144] END max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.791 total time=   0.5s
# [CV 4/5; 43/144] START max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=200
# [CV 4/5; 43/144] END max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=200;, score=0.791 total time=   0.2s
# [CV 4/5; 44/144] START max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=500
# [CV 4/5; 44/144] END max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=500;, score=0.791 total time=   0.5s
# [CV 3/5; 48/144] START max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=500
# [CV 3/5; 48/144] END max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=500;, score=0.753 total time=   0.5s
# [CV 3/5; 51/144] START max_depth=3, max_features=log2, min_samples_leaf=5, n_estimators=200
# [CV 3/5; 51/144] END max_depth=3, max_features=log2, min_samples_leaf=5, n_estimators=200;, score=0.773 total time=   0.3s
# [CV 2/5; 53/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=50
# [CV 2/5; 53/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=50;, score=0.740 total time=   0.1s
# [CV 4/5; 53/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=50
# [CV 4/5; 53/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=50;, score=0.804 total time=   0.1s
# [CV 1/5; 54/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=100
# [CV 1/5; 54/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=100;, score=0.714 total time=   0.2s
# [CV 2/5; 55/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=200
# [CV 2/5; 55/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=200;, score=0.747 total time=   0.2s
# [CV 4/5; 56/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=500
# [CV 4/5; 56/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=500;, score=0.797 total time=   0.5s
# [CV 1/5; 60/144] START max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=500
# [CV 1/5; 60/144] END max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=500;, score=0.727 total time=   0.6s
# [CV 3/5; 63/144] START max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=200
# [CV 3/5; 63/144] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=200;, score=0.740 total time=   0.2s
# [CV 4/5; 64/144] START max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=500
# [CV 4/5; 64/144] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=500;, score=0.804 total time=   0.6s
# [CV 2/5; 2/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100
# [CV 2/5; 2/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.740 total time=   0.1s
# [CV 5/5; 3/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200
# [CV 5/5; 3/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.758 total time=   0.2s
# [CV 1/5; 5/144] START max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=50
# [CV 1/5; 5/144] END max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=50;, score=0.734 total time=   0.1s
# [CV 3/5; 5/144] START max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=50
# [CV 3/5; 5/144] END max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=50;, score=0.747 total time=   0.1s
# [CV 3/5; 6/144] START max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=100
# [CV 3/5; 6/144] END max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=100;, score=0.760 total time=   0.1s
# [CV 2/5; 7/144] START max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=200
# [CV 2/5; 7/144] END max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=200;, score=0.740 total time=   0.3s
# [CV 2/5; 9/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=50
# [CV 2/5; 9/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=50;, score=0.734 total time=   0.1s
# [CV 1/5; 10/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=100
# [CV 1/5; 10/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=100;, score=0.727 total time=   0.1s
# [CV 4/5; 10/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=100
# [CV 4/5; 10/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=100;, score=0
144] START max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=500
# [CV 2/5; 44/144] END max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=500;, score=0.721 total time=   0.4s
# [CV 3/5; 46/144] START max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=100
# [CV 3/5; 46/144] END max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=100;, score=0.747 total time=   0.2s
# [CV 4/5; 47/144] START max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=200
# [CV 4/5; 47/144] END max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=200;, score=0.791 total time=   0.2s
# [CV 5/5; 48/144] START max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=500
# [CV 5/5; 48/144] END max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=500;, score=0.758 total time=   0.5s
# [CV 1/5; 52/144] START max_depth=3, max_features=log2, min_samples_leaf=5, n_estimators=500
# [CV 1/5; 52/144] END max_depth=3, max_features=log2, min_samples_leaf=5, n_estimators=500;, score=0.740 total time=   0.5s
# [CV 5/5; 54/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=100
# [CV 5/5; 54/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 5/5; 55/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=200
# [CV 5/5; 55/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=200;, score=0.784 total time=   0.2s
# [CV 1/5; 57/144] START max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=50
# [CV 1/5; 57/144] END max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=50;, score=0.747 total time=   0.1s
# [CV 3/5; 57/144] START max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=50
# [CV 3/5; 57/144] END max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=50;, score=0.740 total time=   0.1s
# [CV 5/5; 57/144] START max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=50
# ...
# [CV 4/5; 7/144] START max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=200
# [CV 4/5; 7/144] END max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=200;, score=0.758 total time=   0.2s
# [CV 1/5; 9/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=50
# [CV 1/5; 9/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=50;, score=0.727 total time=   0.1s
# [CV 4/5; 9/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=50
# [CV 4/5; 9/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=50;, score=0.784 total time=   0.1s
# [CV 2/5; 10/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=100
# [CV 2/5; 10/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=100;, score=0.734 total time=   0.2s
# [CV 2/5; 11/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=200
# [CV 2/5; 11/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=200;, score=0.727 total time=   0.3s
# [CV 5/5; 12/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=500
# [CV 5/5; 12/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=500;, score=0.758 total time=   0.4s
# [CV 5/5; 15/144] START max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=200
# [CV 5/5; 15/144] END max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=200;, score=0.765 total time=   0.3s
# [CV 3/5; 17/144] START max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=50
# [CV 3/5; 17/144] END max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=50;, score=0.740 total time=   0.1s
# [CV 2/5; 18/144] START max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=100
# [CV 2/5; 18/144] END max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=100;, score=0.747 total time=   0.1s
# [CV 4/5; 19/144] START max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=200
# [CV 4/5; 19/144] END max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=200;, score=0.771 total time=   0.3s
# [CV 3/5; 21/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=50
# [CV 3/5; 21/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=50;, score=0.740 total time=   0.2s
# [CV 2/5; 22/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=100
# [CV 2/5; 22/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=100;, score=0.747 total time=   0.2s
# [CV 4/5; 23/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=200
# [CV 4/5; 23/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=200;, score=0.771 total time=   0.2s
# [CV 5/5; 24/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=500
# [CV 5/5; 24/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=500;, score=0.758 total time=   0.6s
# [CV 1/5; 28/144] START max_depth=2, max_features=None, min_samples_leaf=5, n_estimators=500
# [CV 1/5; 28/144] END max_depth=2, max_features=None, min_samples_leaf=5, n_estimators=500;, score=0.734 total time=   0.7s
# [CV 1/5; 32/144] START max_depth=2, max_features=None, min_samples_leaf=10, n_estimators=500
# [CV 1/5; 32/144] END max_depth=2, max_features=None, min_samples_leaf=10, n_estimators=500;, score=0.734 total time=   0.7s
# [CV 3/5; 35/144] START max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=200
# [CV 3/5; 35/144] END max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=200;, score=0.727 total time=   0.2s
# [CV 5/5; 36/144] START max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=500
# [CV 5/5; 36/144] END max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=500;, score=0.765 total time=   0.5s
# [CV 5/5; 39/144] START max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=200
# [CV 5/5; 39/144] END max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.745 total time=   0.2s
# [CV 5/5; 40/144] START max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 5/5; 40/144] END max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.745 total time=   0.5s
# [CV 1/5; 44/144] START max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=500
# [CV 1/5; 44/144] END max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=500;, score=0.734 total time=   0.5s
# [CV 5/5; 46/144] START max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=100
# [CV 5/5; 46/144] END max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 2/5; 47/144] START max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=200
# [CV 2/5; 47/144] END max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=200;, score=0.721 total time=   0.2s
# [CV 4/5; 48/144] START max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=500
# [CV 4/5; 48/144] END max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=500;, score=0.784 total time=   0.6s
# [CV 4/5; 52/144] START max_depth=3, max_features=log2, min_samples_leaf=5, n_estimators=500
# [CV 4/5; 52/144] END max_depth=3, max_features=log2, min_samples_leaf=5, n_estimators=500;, score=0.797 total time=   0.6s
# [CV 1/5; 56/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=500
# [CV 1/5; 56/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=500;, score=0.740 total time=   0.5s
# [CV 5/5; 58/144] START max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=100
# [CV 5/5; 58/144] END max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=100;, score=0.791 total time=   0.2s
# [CV 3/5; 60/144] START max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=500
# [CV 3/5; 60/144] END max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=500;, score=0.760 total time=   0.6s
# [CV 5/5; 63/144] START max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=200
# [CV 5/5; 63/144] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=200;, score=0.771 total time=   0.4s
# [CV 4/5; 65/144] START max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=50
# [CV 4/5; 65/144] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=50;, score=0.797 total time=   0.1s
# [CV 2/5; 66/144] START max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=100
# [CV 2/5; 66/144] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=100;, score=0.714 total time=   0.1s
# [CV 5/5; 66/144] START max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=100
# [CV 5/5; 66/144] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 1/5; 68/144] START max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=500
# [CV 1/5; 68/144] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=500;, score=0.740 total time=   0.7s
# [CV 2/5; 71/144] START max_depth=3, max_features=None, min_samples_leaf=20, n_estimators=200
# [CV 2/5; 71/144] END max_depth=3, max_features=None, min_samples_leaf=20, n_estimators=200;, score=0.708 total time=   0.3s[CV 3/5; 1/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50
# [CV 3/5; 1/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.747 total time=   0.1s
# [CV 4/5; 2/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100
# [CV 4/5; 2/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.765 total time=   0.2s
# [CV 3/5; 4/144] START max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 3/5; 4/144] END max_depth=2, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.747 total time=   0.6s
# [CV 2/5; 8/144] START max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=500
# [CV 2/5; 8/144] END max_depth=2, max_features=sqrt, min_samples_leaf=10, n_estimators=500;, score=0.734 total time=   0.5s
# [CV 1/5; 12/144] START max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=500
# [CV 1/5; 12/144] END max_depth=2, max_features=sqrt, min_samples_leaf=20, n_estimators=500;, score=0.740 total time=   0.5s
# [CV 4/5; 14/144] START max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=100
# [CV 4/5; 14/144] END max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 1/5; 16/144] START max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=500
# [CV 1/5; 16/144] END max_depth=2, max_features=log2, min_samples_leaf=5, n_estimators=500;, score=0.734 total time=   0.6s
# [CV 1/5; 19/144] START max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=200
# [CV 1/5; 19/144] END max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=200;, score=0.734 total time=   0.3s
# [CV 5/5; 20/144] START max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=500
# [CV 5/5; 20/144] END max_depth=2, max_features=log2, min_samples_leaf=10, n_estimators=500;, score=0.758 total time=   0.4s
# [CV 1/5; 24/144] START max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=500
# [CV 1/5; 24/144] END max_depth=2, max_features=log2, min_samples_leaf=20, n_estimators=500;, score=0.734 total time=   0.7s
# [CV 3/5; 27/144] START max_depth=2, max_features=None, min_samples_leaf=5, n_estimators=200
# [CV 3/5; 27/144] END max_depth=2, max_features=None, min_samples_leaf=5, n_estimators=200;, score=0.727 total time=   0.2s
# [CV 5/5; 28/144] START max_depth=2, max_features=None, min_samples_leaf=5, n_estimators=500
# [CV 5/5; 28/144] END max_depth=2, max_features=None, min_samples_leaf=5, n_estimators=500;, score=0.758 total time=   0.6s
# [CV 3/5; 31/144] START max_depth=2, max_features=None, min_samples_leaf=10, n_estimators=200
# [CV 3/5; 31/144] END max_depth=2, max_features=None, min_samples_leaf=10, n_estimators=200;, score=0.727 total time=   0.2s
# [CV 5/5; 32/144] START max_depth=2, max_features=None, min_samples_leaf=10, n_estimators=500
# [CV 5/5; 32/144] END max_depth=2, max_features=None, min_samples_leaf=10, n_estimators=500;, score=0.758 total time=   0.6s
# [CV 5/5; 35/144] START max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=200
# [CV 5/5; 35/144] END max_depth=2, max_features=None, min_samples_leaf=20, n_estimators=200;, score=0.758 total time=   0.3s
# [CV 4/5; 37/144] START max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=50
# [CV 4/5; 37/144] END max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.791 total time=   0.2s
# [CV 2/5; 38/144] START max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=100
# [CV 2/5; 38/144] END max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.721 total time=   0.2s
# [CV 2/5; 40/144] START max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=500
# [CV 2/5; 40/144] END max_depth=3, max_features=sqrt, min_samples_leaf=5, n_estimators=500;, score=0.727 total time=   0.6s
# [CV 2/5; 43/144] START max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=200
# [CV 2/5; 43/144] END max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=200;, score=0.727 total time=   0.3s
# [CV 5/5; 44/144] START max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=500
# [CV 5/5; 44/144] END max_depth=3, max_features=sqrt, min_samples_leaf=10, n_estimators=500;, score=0.758 total time=   0.4s
# [CV 2/5; 48/144] START max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=500
# [CV 2/5; 48/144] END max_depth=3, max_features=sqrt, min_samples_leaf=20, n_estimators=500;, score=0.721 total time=   0.6s
# [CV 2/5; 52/144] START max_depth=3, max_features=log2, min_samples_leaf=5, n_estimators=500
# [CV 2/5; 52/144] END max_depth=3, max_features=log2, min_samples_leaf=5, n_estimators=500;, score=0.727 total time=   0.4s
# [CV 2/5; 54/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=100
# [CV 2/5; 54/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=100;, score=0.727 total time=   0.1s
# [CV 1/5; 55/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=200
# [CV 1/5; 55/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=200;, score=0.727 total time=   0.2s
# [CV 3/5; 56/144] START max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=500
# [CV 3/5; 56/144] END max_depth=3, max_features=log2, min_samples_leaf=10, n_estimators=500;, score=0.773 total time=   0.5s
# [CV 3/5; 59/144] START max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=200
# [CV 3/5; 59/144] END max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=200;, score=0.753 total time=   0.2s
# [CV 4/5; 60/144] START max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=500
# [CV 4/5; 60/144] END max_depth=3, max_features=log2, min_samples_leaf=20, n_estimators=500;, score=0.791 total time=   0.5s
# [CV 1/5; 64/144] START max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=500
# [CV 1/5; 64/144] END max_depth=3, max_features=None, min_samples_leaf=5, n_estimators=500;, score=0.740 total time=   0.7s
# [CV 3/5; 67/144] START max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=200
# [CV 3/5; 67/144] END max_depth=3, max_features=None, min_samples_leaf=10, n_estimators=200;, score=0.740 total time=   0.4s
# [CV 1/5; 69/144] START max_depth=3, max_features=None, min_samples_leaf=20, n_estimators=50
# [CV 1/5; 69/144] END max_depth=3, max_features=None, min_samples_leaf=20, n_estimators=50;, score=0.740 total time=   0.1s
# [CV 4/5; 69/144] START max_depth=3, max_features=None, min_samples_leaf=20, n_estimators=50
# [CV 4/5; 69/144] END max_depth=3, max_features=None, min_samples_leaf=20, n_estimators=50;, score=0.804 total time=   0.1s
# [CV 1/5; 70/144] START max_depth=3, max_features=None, min_samples_leaf=20, n_estimators=100
# [CV 1/5; 70/144] END max_depth=3, max_features=None, min_samples_leaf=20, n_estimators=100;, score=0.747 total time=   0.2s
# [CV 3/5; 71/144] START max_depth=3, max_features=None, min_samples_leaf=20, n_estimators=200
# [CV 3/5; 71/144] END max_depth=3, max_features=None, min_samples_leaf=20, n_estimators=200;, score=0.747 total time=   0.4s
# [CV 3/5; 73/144] START max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=50
# [CV 3/5; 73/144] END max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=50;, score=0.760 total time=   0.1s
# [CV 1/5; 74/144] START max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=100
# [CV 1/5; 74/144] END max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=100;, score=0.779 total time=   0.2s
# [CV 1/5; 75/144] START max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=200
# [CV 1/5; 75/144] END max_depth=5, max_features=sqrt, min_samples_leaf=5, n_estimators=200;, score=0.773 total time=   0.4s
# [CV 3/5; 77/144] START max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=50
# [CV 3/5; 77/144] END max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=50;, score=0.773 total time=   0.1s
# [CV 4/5; 77/144] START max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=50
# [CV 4/5; 77/144] END max_depth=5, max_features=sqrt, min_samples_leaf=10, n_estimators=50;, score=0.804 total time=   0.1s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5, None],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_leaf': [5, 10, 20],
#                          'n_estimators': [50, 100, 200, 500]},
#              scoring='accuracy', verbose=10)
